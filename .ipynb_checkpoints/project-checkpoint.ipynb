# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
from pytrends.request import TrendReq

columns = ['City', 'Big Data Job Offers', 'Data Science Job Offers', 'Machine Learning Job Offers']
europe_cities = {}
latam_cities = {}
usa_cities = {}

# %%
req1 = TrendReq()
req1.build_payload(kw_list=['big data', 'data science', 'machine learning'])

trends = req1.interest_by_region('CITY')
trendy = trends.drop(trends[(trends['big data'] == 0) & (trends['data science'] == 0) & (trends['machine learning'] == 0)].index)
trendy.sort_index()
# Out:
#                   big data  data science  machine learning
# geoName
# Bangkok                 57            18                25
# Barcelona               66            11                23
# Bengaluru               44            20                36
# Berlin                  45            17                38
# Chennai                 55            17                28
# Chicago                 35            32                33
# Diadema                 71            11                18
# Gurgaon                 47            20                33
# Howrah                  55            19                26
# Hyderabad               46            25                29
# Istanbul                48            14                38
# Jakarta                 64            13                23
# Kuala Lumpur            60            18                22
# London                  46            21                33
# Los Angeles             36            26                38
# Madrid                  75             8                17
# Melbourne               45            26                29
# Mexico City             67            12                21
# Milan                   61            12                27
# Moscow                  49            15                36
# Mumbai                  48            20                32
# New Delhi               47            23                30
# New York                40            28                32
# Noida                   50            18                32
# Paris                   64            12                24
# Pimpri-Chinchwad        53            18                29
# Pune                    47            19                34
# San Francisco           30            29                41
# San Jose                31            23                46
# Seoul                   47            10                43
# Singapore               45            20                35
# Sydney                  45            25                30
# Toronto                 44            19                37
# Warsaw                  58            13                29
# Washington              42            35                23

# %%
trends.drop(trends[(trends['big data'] != 0) & (trends['data science'] != 0) & (trends['machine learning'] != 0)].index).sort_index()
# Out:
#                   big data  data science  machine learning
# geoName
# Ahmedabad                0             0                 0
# Amsterdam                0             0                 0
# Atlanta                  0             0                 0
# Austin                   0             0                 0
# Belo Horizonte           0             0                 0
# Bogotá                   0             0                 0
# Boston                   0             0                 0
# Brisbane                 0             0                 0
# Brussels                 0             0                 0
# Buenos Aires             0             0                 0
# Casablanca               0             0                 0
# Charlotte                0             0                 0
# Coimbatore               0             0                 0
# Copenhagen               0             0                 0
# Dallas                   0             0                 0
# Dubai                    0             0                 0
# Dublin                   0             0                 0
# Frankfurt                0             0                 0
# Hamburg                  0             0                 0
# Hanoi                    0             0                 0
# Helsinki                 0             0                 0
# Ho Chi Minh City         0             0                 0
# Houston                  0             0                 0
# Kiev                     0             0                 0
# Kolkata                  0             0                 0
# Lagos                    0             0                 0
# Leesburg                 0             0                 0
# Montreal                 0             0                 0
# Munich                   0             0                 0
# Nairobi                  0             0                 0
# Ottawa                   0             0                 0
# Philadelphia             0             0                 0
# Rio de Janeiro           0             0                 0
# Rome                     0             0                 0
# San Diego                0             0                 0
# Santiago                 0             0                 0
# Seattle                  0             0                 0
# Stockholm                0             0                 0
# Sunnyvale                0             0                 0
# São Paulo                0             0                 0
# Tehran                   0             0                 0
# Tel Aviv-Yafo            0             0                 0
# Tunis                    0             0                 0
# Utrecht                  0             0                 0
# Vienna                   0             0                 0
# Zürich                   0             0                 0

# %%
def buildDic(dic, filename):
    f = open(filename, 'r')
    for line in f:
        data = line.strip().split(",")
        city = data[0]
        job_offer = data[1]
        total_count = int(data[2])
        if city not in dic:
            dic[city] = {}
        dic[city][job_offer] = total_count

# %%
buildDic(europe_cities,"europe.csv")
buildDic(latam_cities, "latinAmerica.csv")
buildDic(usa_cities,"usa.csv")

# %%
def addRows(df, dic):
    for k, v in dic.items():
        df2 = pd.DataFrame(data=[[k, v['Big Data'], v['Data Science'], v['Machine Learning']]], columns=columns)
        df = df.append(df2, ignore_index=True)
    df.index = [(i+1) for i in range(len(dic))]
    return df

# %%
def total(df):
    df['Total New Tech Job Offers'] = df.apply(lambda x: x[columns[1]] + x[columns[2]] + x[columns[3]], axis=1)

# %%
maindf = pd.DataFrame(columns=columns)

# %%
europedf = pd.DataFrame(columns=columns)
europedf = addRows(europedf, europe_cities)

# %%
usadf = pd.DataFrame(columns=columns)
usadf = addRows(usadf, usa_cities)

# %%
latamdf = pd.DataFrame(columns=columns)
latamdf = addRows(latamdf, latam_cities)

# %%
maindf = maindf.append([europedf, usadf, latamdf], ignore_index=True)
maindf = maindf.sort_values('City')
maindf = maindf.reset_index(drop=True)
total(maindf)

# %%
maindf
# Out:
#               City Big Data Job Offers Data Science Job Offers  \
# 0        Amsterdam                1291                    1211
# 1          Atlanta                1599                     265
# 2           Austin                 938                     349
# 3        Barcelona                 417                     334
# 4   Belo Horizonte                  12                       8
# 5           Berlin                1022                     982
# 6           Bogota                  41                      51
# 7           Boston                2234                    6702
# 8         Bruselas                 649                     860
# 9         Budapest                 302                     372
# 10    Buenos Aires                 172                     167
# 11         Chicago                2045                     333
# 12          Dallas                1596                     225
# 13          Dublin                 617                    1184
# 14        Estambul                  90                     152
# 15       Estocolmo                 364                     394
# 16       Frankfurt                 472                     355
# 17        Hamburgo                 324                     280
# 18         Houston                 674                      98
# 19            Kiev                 273                     262
# 20            Lima                  25                      19
# 21          Lisboa                 252                     294
# 22          London                4981                    5395
# 23     Los Angeles                1592                     306
# 24          Madrid                 528                     382
# 25     Mexico City                 195                     226
# 26          Milano                 284                     322
# 27          Moscow                 171                     119
# 28          Munich                 974                     853
# 29        New York                5397                   10074
# 30           Paris                3707                    1835
# 31            Roma                 147                      88
# 32   San Francisco                3867                    7657
# 33        Santiago                 102                      61
# 34       Sao Paulo                 274                     295
# 35         Seattle                3593                     853
# 36          Vienna                 162                     163
# 37      Washington                4291                     861
# 38          Zurich                 330                     551
#
#    Machine Learning Job Offers  Total New Tech Job Offers
# 0                          494                       2996
# 1                          371                       2235
# 2                          517                       1804
# 3                          158                        909
# 4                           11                         31
# 5                          688                       2692
# 6                           11                        103
# 7                         1271                      10207
# 8                          196                       1705
# 9                           81                        755
# 10                         178                        517
# 11                         640                       3018
# 12                         454                       2275
# 13                         259                       2060
# 14                          39                        281
# 15                         217                        975
# 16                         170                        997
# 17                         182                        786
# 18                         269                       1041
# 19                         110                        645
# 20                          20                         64
# 21                         132                        678
# 22                        2689                      13065
# 23                         597                       2495
# 24                         165                       1075
# 25                          60                        481
# 26                         138                        744
# 27                          88                        378
# 28                         578                       2405
# 29                        2196                      17667
# 30                        1292                       6834
# 31                          51                        286
# 32                        2314                      13838
# 33                          49                        212
# 34                         112                        681
# 35                        3153                       7599
# 36                          64                        389
# 37                        1158                       6310
# 38                         220                       1101

# %%
total(europedf)
total(latamdf)
total(usadf)

# %%
europedf
# Out:
#          City Big Data Job Offers Data Science Job Offers  \
# 1   Amsterdam                1291                    1211
# 2   Barcelona                 417                     334
# 3      Berlin                1022                     982
# 4    Bruselas                 649                     860
# 5    Budapest                 302                     372
# 6      Dublin                 617                    1184
# 7    Estambul                  90                     152
# 8   Estocolmo                 364                     394
# 9   Frankfurt                 472                     355
# 10   Hamburgo                 324                     280
# 11       Kiev                 273                     262
# 12     Lisboa                 252                     294
# 13     London                4981                    5395
# 14     Madrid                 528                     382
# 15     Milano                 284                     322
# 16     Moscow                 171                     119
# 17     Munich                 974                     853
# 18      Paris                3707                    1835
# 19       Roma                 147                      88
# 20     Vienna                 162                     163
# 21     Zurich                 330                     551
#
#    Machine Learning Job Offers  Total New Tech Job Offers
# 1                          494                       2996
# 2                          158                        909
# 3                          688                       2692
# 4                          196                       1705
# 5                           81                        755
# 6                          259                       2060
# 7                           39                        281
# 8                          217                        975
# 9                          170                        997
# 10                         182                        786
# 11                         110                        645
# 12                         132                        678
# 13                        2689                      13065
# 14                         165                       1075
# 15                         138                        744
# 16                          88                        378
# 17                         578                       2405
# 18                        1292                       6834
# 19                          51                        286
# 20                          64                        389
# 21                         220                       1101

# %%
latamdf
# Out:
#              City Big Data Job Offers Data Science Job Offers  \
# 1  Belo Horizonte                  12                       8
# 2          Bogota                  41                      51
# 3    Buenos Aires                 172                     167
# 4            Lima                  25                      19
# 5     Mexico City                 195                     226
# 6        Santiago                 102                      61
# 7       Sao Paulo                 274                     295
#
#   Machine Learning Job Offers  Total New Tech Job Offers
# 1                          11                         31
# 2                          11                        103
# 3                         178                        517
# 4                          20                         64
# 5                          60                        481
# 6                          49                        212
# 7                         112                        681

# %%
usadf
# Out:
#              City Big Data Job Offers Data Science Job Offers  \
# 1         Atlanta                1599                     265
# 2          Austin                 938                     349
# 3          Boston                2234                    6702
# 4         Chicago                2045                     333
# 5          Dallas                1596                     225
# 6         Houston                 674                      98
# 7     Los Angeles                1592                     306
# 8        New York                5397                   10074
# 9   San Francisco                3867                    7657
# 10        Seattle                3593                     853
# 11     Washington                4291                     861
#
#    Machine Learning Job Offers  Total New Tech Job Offers
# 1                          371                       2235
# 2                          517                       1804
# 3                         1271                      10207
# 4                          640                       3018
# 5                          454                       2275
# 6                          269                       1041
# 7                          597                       2495
# 8                         2196                      17667
# 9                         2314                      13838
# 10                        3153                       7599
# 11                        1158                       6310

# %%
compdf = pd.DataFrame(index=['Europe','Latam','USA'], columns=['Big Data','Data Science','Machine Learning','Total Count'])
compdf.loc['Europe'] = [europedf[columns[1]].sum(),europedf[columns[2]].sum(),europedf[columns[3]].sum(),europedf.iloc[:,-1].sum()]
compdf.loc['Latam'] = [latamdf[columns[1]].sum(),latamdf[columns[2]].sum(),latamdf[columns[3]].sum(),latamdf.iloc[:,-1].sum()]
compdf.loc['USA'] = [usadf[columns[1]].sum(),usadf[columns[2]].sum(),usadf[columns[3]].sum(),usadf.iloc[:,-1].sum()]
compdf.plot.bar()

# %%
gdp_df = pd.read_csv('data/cities_gdp.csv')

# %%
gdp_df = gdp_df.drop(columns=['METRO_ID','Variables','TIME','Unit Code','Unit','PowerCode Code','PowerCode','Reference Period Code','Reference Period','Flag Codes','Flags'])
gdp_df = gdp_df.sort_values(by='Metropolitan areas')
gdp_df.columns = ['City','GDP']

# %%
gdp_df.head()
# Out:
#                  City       GDP
# 0              Aachen  19496.51
# 1  Acapulco de Juárez   6125.81
# 2            Adelaide  47478.78
# 3      Aguascalientes  15768.23
# 4               Akron  24969.01

# %%
gdp_df = gdp_df.loc[(gdp_df['VAR'] == 'GDP') & (gdp_df['Year'] == 2012)]
gdp_df = gdp_df.reset_index(drop=True)
gdp_df = gdp_df.drop(columns=['VAR','Year'])

# %%
merge = pd.merge(maindf, gdp_df, how='inner', on='City')

# %%
merge = pd.merge(maindf, gdp_df, how='outer', on='City')
merge = merge[merge['Big Data Job Offers'] != 'NaN']

# %%
merge
# Out:
#              City Big Data Job Offers Data Science Job Offers  \
# 0       Amsterdam                1291                    1211
# 1         Atlanta                1599                     265
# 2          Austin                 938                     349
# 3       Barcelona                 417                     334
# 4          Berlin                1022                     982
# 5          Boston                2234                    6702
# 6        Budapest                 302                     372
# 7         Chicago                2045                     333
# 8          Dallas                1596                     225
# 9          Dublin                 617                    1184
# 10      Frankfurt                 472                     355
# 11        Houston                 674                      98
# 12         London                4981                    5395
# 13    Los Angeles                1592                     306
# 14         Madrid                 528                     382
# 15    Mexico City                 195                     226
# 16         Munich                 974                     853
# 17       New York                5397                   10074
# 18          Paris                3707                    1835
# 19  San Francisco                3867                    7657
# 20       Santiago                 102                      61
# 21        Seattle                3593                     853
# 22         Vienna                 162                     163
# 23     Washington                4291                     861
# 24         Zurich                 330                     551
#
#    Machine Learning Job Offers  Total New Tech Job Offers         GDP
# 0                          494                       2996   121289.27
# 1                          371                       2235   263711.72
# 2                          517                       1804    96379.31
# 3                          158                        909   135803.15
# 4                          688                       2692   165376.72
# 5                         1271                      10207   305833.34
# 6                           81                        755   102939.82
# 7                          640                       3018   554230.82
# 8                          454                       2275   304270.25
# 9                          259                       2060    95902.65
# 10                         170                        997   143516.43
# 11                         269                       1041   470838.44
# 12                        2689                      13065   652583.23
# 13                         597                       2495   891793.72
# 14                         165                       1075   281713.66
# 15                          60                        481   410907.94
# 16                         578                       2405   184700.85
# 17                        2196                      17667  1215233.96
# 18                        1292                       6834   707134.27
# 19                        2314                      13838   568072.44
# 20                          49                        212   164436.24
# 21                        3153                       7599   231514.38
# 22                          64                        389   129515.54
# 23                        1158                       6310   442758.65
# 24                         220                       1101    77011.48

# %%
merge['Total New Tech Job Offers'].corr(merge['GDP'])
# Out:
# 0.679559548960563

# %%
merge.plot.scatter(x='Total New Tech Job Offers',y='GDP')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-728ab238a1a2> in <module>()
# ----> 1 merge.plot.scatter(x='Total New Tech Job Offers',y='GDP',kind='line')
#
# ~/Desktop/analisis/env/lib/python3.6/site-packages/pandas/plotting/_core.py in scatter(self, x, y, s, c, **kwds)
#    2853         axes : matplotlib.AxesSubplot or np.array of them
#    2854         """
# -> 2855         return self(kind='scatter', x=x, y=y, c=c, s=s, **kwds)
#    2856
#    2857     def hexbin(self, x, y, C=None, reduce_C_function=None, gridsize=None,
#
# TypeError: FramePlotMethods object got multiple values for keyword argument 'kind'
