# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
from pytrends.request import TrendReq

columns = ['City', 'Big Data Job Offers', 'Data Science Job Offers', 'Machine Learning Job Offers']
europe_cities = {}
latam_cities = {}
usa_cities = {}

# %%
req1 = TrendReq()
req1.build_payload(kw_list=['big data', 'data science', 'machine learning'])

trends = req1.interest_by_region('CITY')
trendy = trends.drop(trends[(trends['big data'] == 0) & (trends['data science'] == 0) & (trends['machine learning'] == 0)].index)
trendy.sort_index()
# Out:
#                   big data  data science  machine learning
# geoName
# Bangkok                 55            17                28
# Barcelona               65            12                23
# Bengaluru               44            20                36
# Berlin                  46            18                36
# Bogotá                  72             9                19
# Chennai                 55            17                28
# Chicago                 35            32                33
# Diadema                 72            10                18
# Gurgaon                 48            20                32
# Howrah                  54            19                27
# Hyderabad               47            24                29
# Istanbul                49            14                37
# Jakarta                 66            13                21
# London                  45            22                33
# Madrid                  74             8                18
# Melbourne               43            28                29
# Milan                   59            12                29
# Mumbai                  49            20                31
# New Delhi               46            22                32
# New York                40            28                32
# Noida                   51            17                32
# Paris                   64            10                26
# Pimpri-Chinchwad        53            18                29
# Pune                    45            20                35
# San Francisco           28            30                42
# San Jose                31            22                47
# Seoul                   46            10                44
# Singapore               45            20                35
# Sydney                  45            25                30
# Toronto                 43            19                38
# Warsaw                  58            16                26
# Washington              43            33                24

# %%
trends.drop(trends[(trends['big data'] != 0) & (trends['data science'] != 0) & (trends['machine learning'] != 0)].index).sort_index()
# Out:
#                   big data  data science  machine learning
# geoName
# Ahmedabad                0             0                 0
# Amsterdam                0             0                 0
# Atlanta                  0             0                 0
# Austin                   0             0                 0
# Boston                   0             0                 0
# Brisbane                 0             0                 0
# Budapest                 0             0                 0
# Buenos Aires             0             0                 0
# Cambridge                0             0                 0
# Casablanca               0             0                 0
# Coimbatore               0             0                 0
# Cologne                  0             0                 0
# Copenhagen               0             0                 0
# Dallas                   0             0                 0
# Dhaka                    0             0                 0
# Dubai                    0             0                 0
# Dublin                   0             0                 0
# Frankfurt                0             0                 0
# Hamburg                  0             0                 0
# Hanoi                    0             0                 0
# Helsinki                 0             0                 0
# Ho Chi Minh City         0             0                 0
# Homagama                 0             0                 0
# Houston                  0             0                 0
# Indore                   0             0                 0
# Kiev                     0             0                 0
# Kochi                    0             0                 0
# Kolkata                  0             0                 0
# Kuala Lumpur             0             0                 0
# Leesburg                 0             0                 0
# Los Angeles              0             0                 0
# Lyon                     0             0                 0
# Mexico City              0             0                 0
# Montreal                 0             0                 0
# Moscow                   0             0                 0
# Munich                   0             0                 0
# Nairobi                  0             0                 0
# Philadelphia             0             0                 0
# Phoenix                  0             0                 0
# Rio de Janeiro           0             0                 0
# Rome                     0             0                 0
# San Diego                0             0                 0
# Sandton                  0             0                 0
# Santiago                 0             0                 0
# Seattle                  0             0                 0
# Stockholm                0             0                 0
# São Paulo                0             0                 0
# Tehran                   0             0                 0
# Tel Aviv-Yafo            0             0                 0
# The Hague                0             0                 0
# Tunis                    0             0                 0
# Vienna                   0             0                 0
# Zürich                   0             0                 0

# %%
def buildDic(dic, filename):
    f = open(filename, 'r')
    for line in f:
        data = line.strip().split(",")
        city = data[0]
        job_offer = data[1]
        total_count = int(data[2])
        if city not in dic:
            dic[city] = {}
        dic[city][job_offer] = total_count

# %%
buildDic(europe_cities,"europe.csv")
buildDic(latam_cities, "latinAmerica.csv")
buildDic(usa_cities,"usa.csv")

# %%
def addRows(df, dic):
    for k, v in dic.items():
        df2 = pd.DataFrame(data=[[k, v['Big Data'], v['Data Science'], v['Machine Learning']]], columns=columns)
        df = df.append(df2, ignore_index=True)
    df.index = [(i+1) for i in range(len(dic))]
    return df

# %%
def total(df):
    df['Total New Tech Job Offers'] = df.apply(lambda x: x[columns[1]] + x[columns[2]] + x[columns[3]], axis=1)

# %%
maindf = pd.DataFrame(columns=columns)

# %%
europedf = pd.DataFrame(columns=columns)
europedf = addRows(europedf, europe_cities)

# %%
usadf = pd.DataFrame(columns=columns)
usadf = addRows(usadf, usa_cities)

# %%
latamdf = pd.DataFrame(columns=columns)
latamdf = addRows(latamdf, latam_cities)

# %%
maindf = maindf.append([europedf, usadf, latamdf], ignore_index=True)
total(maindf)

# %%
maindf
# Out:
#               City Big Data Job Offers Data Science Job Offers  \
# 1        Amsterdam                1291                    1211
# 2          Atlanta                1599                     265
# 3           Austin                 938                     349
# 4        Barcelona                 417                     334
# 5   Belo Horizonte                  12                       8
# 6           Berlin                1022                     982
# 7           Bogota                  41                      51
# 8           Boston                2234                    6702
# 9         Bruselas                 649                     860
# 10        Budapest                 302                     372
# 11    Buenos Aires                 172                     167
# 12         Chicago                2045                     333
# 13          Dallas                1596                     225
# 14          Dublin                 617                    1184
# 15        Estambul                  90                     152
# 16       Estocolmo                 364                     394
# 17       Frankfurt                 472                     355
# 18        Hamburgo                 324                     280
# 19         Houston                 674                      98
# 20            Kiev                 273                     262
# 21            Lima                  25                      19
# 22          Lisboa                 252                     294
# 23          London                4981                    5395
# 24     Los Angeles                1592                     306
# 25          Madrid                 528                     382
# 26     Mexico City                 195                     226
# 27          Milano                 284                     322
# 28          Moscow                 171                     119
# 29          Munich                 974                     853
# 30        New York                5397                   10074
# 31           Paris                3707                    1835
# 32            Roma                 147                      88
# 33   San Francisco                3867                    7657
# 34        Santiago                 102                      61
# 35       Sao Paulo                 274                     295
# 36         Seattle                3593                     853
# 37          Vienna                 162                     163
# 38      Washington                4291                     861
# 39          Zurich                 330                     551
#
#    Machine Learning Job Offers  Total New Tech Job Offers
# 1                          494                       2996
# 2                          371                       2235
# 3                          517                       1804
# 4                          158                        909
# 5                           11                         31
# 6                          688                       2692
# 7                           11                        103
# 8                         1271                      10207
# 9                          196                       1705
# 10                          81                        755
# 11                         178                        517
# 12                         640                       3018
# 13                         454                       2275
# 14                         259                       2060
# 15                          39                        281
# 16                         217                        975
# 17                         170                        997
# 18                         182                        786
# 19                         269                       1041
# 20                         110                        645
# 21                          20                         64
# 22                         132                        678
# 23                        2689                      13065
# 24                         597                       2495
# 25                         165                       1075
# 26                          60                        481
# 27                         138                        744
# 28                          88                        378
# 29                         578                       2405
# 30                        2196                      17667
# 31                        1292                       6834
# 32                          51                        286
# 33                        2314                      13838
# 34                          49                        212
# 35                         112                        681
# 36                        3153                       7599
# 37                          64                        389
# 38                        1158                       6310
# 39                         220                       1101

# %%
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd8c44bff98>]],
#       dtype=object)
